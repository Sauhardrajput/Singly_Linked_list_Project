# %% [markdown]
#   # singly LinkdList Programs

# %% [markdown]
# # creation of node

# %%
class Node:
    def __init__(self):
        self.info = None
        self.next = None
node = Node()
node.info = "Node"
print(node)
print(node.info)
# Out:
# ...
# Node

# %% [markdown]
# # Creation of LinkedList

# %%
class LinkedList:
    def __init__(self):
        self.start=None
LL=LinkedList()
print(LL)

# %% [markdown]
# # Storing values in LinkedList

# %%
class Node:
    def __init__(self):
        self.info=None
        self.next=None

class LinkedList:
    def __init__(self):
        self.start=None
    
    def display(self):
        temp=self.start
        while(temp.next!= None):
            print(temp.info,end="-->")
            temp=temp.next
        print(temp.info)
        
LL=LinkedList()
node1 = Node()
node1.info = "Sauhard"
node2 = Node()
node2.info = "Ujjwal"
node3 = Node()
node3.info = "Varun"
node4 = Node()
node4.info = "Shubh"
LL.start = node1
node1.next = node2
node2.next = node3
node3.next = node4
LL.display()
# Out:
# Sauhard-->Ujjwal-->Varun-->Shubh

# %% [markdown]
# #  Various Programs of LinkedList

# %%
class Node:
    def __init__(self):
        self.info = None
        self.next = None
        
class Linkedlist:
    def __init__(self):
        self.start = None 
    
    def create(self):
        while(1):
            node = Node()
            node.info = input("Enter info: ")
            if(self.start == None):
                self.start = node
            else:
                temp.next = node
            temp = node 
            choice = input("Do u want to next node? yes/no : ")
            if(choice=="no"):
                break
        print("Linkedlist created successfully.")
    

#Insertion at beginning    
    def insert_at_beg(self):
        if(self.start == None):
            print("No Linkedlist exists.")
        else:
            node = Node()
            node.info = input("Enter element which u want to insert at beginning: ")
            node.next = self.start 
            self.start = node
        print("Insert element at beginning successfully.")
        
#Insertion at last        
    def insert_at_last(self):
        if(self.start == None):
            print("No Linkedlist exists.")
        else:
            temp = self.start 
            while(temp.next!=None):
                temp = temp.next 
            node = Node()
            node.info = input("Enter element which u want to insert at last: ")
            temp.next = node
        print("Insert element at last successfully.")
    
    
#Insertion at Desired Location     
    def insert_after_desired_node(self,elem):
        if(self.start == None):
            print("No Linkedlist exists.")
        else:
            temp = self.start
            while(temp.next is not None and temp.info!=elem):
                temp = temp.next
            if(temp.next is None):
                print("Element not found")
            else:
                node=Node()
                node.info = input("Enter element which u want to insert after node: ")
                node.next = temp.next
                temp.next = node
        print("Insert element after node successfully.")
        
    
#Deletion at beginning
    def delete_at_beg(self):
        if(self.start == None):
            print("No Linkedlist exist")
        else:
            self.start = self.start.next
        print("Deletion at beginning successfull.")
        
        
#Deletion at last
    def delete_at_last(self):
        if(self.start == None):
            print("No Linkedlist exist")
        else:
            temp = self.start 
            prev = None
            while(temp.next!=None):
                prev = temp
                temp = temp.next
            if(prev is None):
                self.strat = None
            else:
                prev.next = None
        print("Deletion at last successfull.")

        
#Deletion at desired location       
    def delete_after_desired_node(self,elem):
        if(self.start == None):
            print("No Linkedlist exist")
        else:
            temp = self.start
            prev = None
            while(temp is not None and temp.info!=elem):
                prev = temp
                temp = temp.next
            if(temp is None):
                print("Element does not exists in LinkedList")
            else:
                if(prev is None):
                    self.start = self.strat.next
                else:
                    prev.next = temp.next
        print("Deletion after node successfull.")
        

#Searching of linkedlist
    def search(self,elem):
        if(self.start == None):
            print("No Linkedlist exist")
        else:
            temp = self.start
            while(temp is not None and temp.info!=elem):
                temp = temp.next
            if(temp is not None):
                print("Element found in Linkedlist")
            else:
                print("Element not found in Linkedlist")
    
            
#Searching in Linkedlist
    def sort(self):
        if(self.start == None):
            print("No Linkedlist exist")
        else:
            i= self.start
            while(i.next is not None):
                j = i.next
                while(j is not None):
                    if(i.info>j.info):
                        temp  = i.info
                        i.info = j.info
                        j.info = temp
                    j= j.next
                i = i.next
            print("LinkedList sorting successfull.")

                
#Reversal of linkedlist
    def reversal(self):
        if(self.start == None):
            print("No Linkedlist exist")
        else:
            prev = None
            curr = self.start
            while(curr is not None):
                temp = curr.next
                curr.next = prev
                prev = curr
                curr = temp
            self.start = prev 
            print("Reversal successfull.")
            
    def display(self):
        temp = self.start
        while(temp.next!=None):
            print(temp.info,end = "--->")
            temp = temp.next
        print(temp.info)
        print("Linked list displayed successfully.")

# %% [markdown]
# # User Choices

# %%
def program():
    LL = Linkedlist()
    while(True): 
        print("""<***************************** LINKEDLIST PROGRAM *****************************>
          1.Create Linkedlist
          2.Insert at beginning
          3.Insert at last
          4.Insert at desired location
          5.Deletion at beginning
          6.Deletion at last
          7.Deletion at desired location
          8.Searching
          9.Sorting
          10.Reversal
          11.Display""")
        choice = int(input("Enter your choice: "))
        if(choice==1):
            LL.create()
        elif(choice==2):
            LL.insert_at_beg()
        elif(choice==3):
            LL.insert_at_last()
        elif(choice==4):
            elem = input("Enter element where you want to insert next element: ")
            LL.insert_after_desired_node(elem)
        elif(choice==5):
            LL.delete_at_beg()
        elif(choice==6):
            LL.delete_at_last()
        elif(choice==7):
            elem = input("Enter element which you want to delete: ")
            LL.delete_after_desired_node(elem)
        elif(choice==8):
            elem = input("Enter element which you want to search: ")
            LL.search(elem)
        elif(choice==9):
            LL.sort()
        elif(choice==10):
            LL.reversal()
        elif(choice==11):
            LL.display()
        elif(choice==12):
            print("Thanks for using my LINKEDLIST PROGRAM: -)")
            break
        else:
            print("Wrong choice......Please Enter correct choice")
program()
# Out:
# <***************************** LINKEDLIST PROGRAM *****************************>
#           1.Create Linkedlist
#           2.Insert at beginning
#           3.Insert at last
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
#           8.Searching
#           9.Sorting
#           10.Reversal
#           11.Display
# Enter your choice: 1
# Enter info: 10
# Do u want to next node? yes/no : yes
# Enter info: 20
# Do u want to next node? yes/no : yes
# Enter info: 30
# Do u want to next node? yes/no : yes
# Enter info: 40
# Do u want to next node? yes/no : no
# Linkedlist created successfully.
# <***************************** LINKEDLIST PROGRAM *****************************>
#           1.Create Linkedlist
#           2.Insert at beginning
#           3.Insert at last
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
# ...
